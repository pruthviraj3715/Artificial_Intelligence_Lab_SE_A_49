# %% [markdown]
# <a href="https://colab.research.google.com/github/pruthviraj3715/Artificial_Intelligence_Lab_SE_A_49/blob/master/experiment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7563abd4-b8cc-4d76-a7e8-9e603c3bb47e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7563abd4-b8cc-4d76-a7e8-9e603c3bb47e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("StudentPerformanceFactors.csv")
data.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
grouped_hours_stats = data.groupby('Gender')['Hours_Studied'].agg([
    'sum', 'count', 'mean', 'median', 'std', 'var', 'min', 'max',
])
display(grouped_hours_stats)
# Out:
#           sum  count       mean  median       std        var  min  max
# Gender
# Female  55874   2793  20.005013    20.0  5.997251  35.967024    1   44
# Male    76103   3814  19.953592    20.0  5.986408  35.837080    1   39

# %% [markdown]
# You can replace `'Gender'` with any other categorical column from your `data` DataFrame if you'd like to group by a different factor.
