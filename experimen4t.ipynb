# %% [markdown]
# <a href="https://colab.research.google.com/github/pruthviraj3715/Artificial_Intelligence_Lab_SE_A_49/blob/master/experimen4t.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# -------------------------------
# 1. Generate Normal Distribution Data
# -------------------------------

# Parameters
mu = 50        # Mean
sigma = 10     # Standard deviation
size = 1000    # Number of samples

# Generate random data
data = np.random.normal(mu, sigma, size)

print("First 10 Generated Values:")
print(data[:10])   # Show only first 10 values

# -------------------------------
# 2. Descriptive Statistics
# -------------------------------

mean = np.mean(data)
median = np.median(data)
variance = np.var(data)
std_dev = np.std(data)

print("Descriptive Statistics:")
print("Mean:", mean)
print("Median:", median)
print("Variance:", variance)
print("Standard Deviation:", std_dev)

# -------------------------------
# 3. Plot Normal Distribution
# -------------------------------

plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)

plt.plot(x, p, 'k', linewidth=2)
plt.title("Normal Distribution (Mean = 50, Std Dev = 10)")
plt.xlabel("Values")
plt.ylabel("Probability Density")
plt.show()

# -------------------------------
# 4. Coin Toss Simulation
# -------------------------------

tosses = 1000
coin = np.random.choice(['H', 'T'], size=tosses)

heads = np.sum(coin == 'H')
tails = np.sum(coin == 'T')

print("\nCoin Toss Simulation:")
print("Total Tosses:", tosses)
print("Heads:", heads)
print("Tails:", tails)
print("Probability of Heads:", heads/tosses)
print("Probability of Tails:", tails/tosses)
# Out:
# First 10 Generated Values:
# [64.16699645 65.67077501 47.88625991 59.66497079 51.01109307 43.49168461
#  63.98270282 33.90816855 41.72056452 46.03120281]
# Descriptive Statistics:
# Mean: 49.363855023284415
# Median: 49.30995142208199
# Variance: 98.56873387946935
# Standard Deviation: 9.928178779588396
# Coin Toss Simulation:
# Total Tosses: 1000
# Heads: 539
# Tails: 461
# Probability of Heads: 0.539
# Probability of Tails: 0.461
